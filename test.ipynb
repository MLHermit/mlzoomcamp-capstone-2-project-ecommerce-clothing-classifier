# %%
import requests

# %%
link = 'http://localhost:8000/predict'
file_path = 'output 1.png'

# %%
with open(file_path, 'rb') as f:
    files = {'file': f}
    response = requests.post(link, files=files)
    print(response.status_code)
    print(response.json())
# Out:
# 200
# {'predicted_class': 8}
